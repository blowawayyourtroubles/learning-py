# %%
# FUNCIONES DE TEXTO Y OPERADORES DE COMPARACIÓN EN PYTHON
print("=== MANIPULACIÓN DE TEXTOS Y COMPARACIONES ===\n")

# 1. Strings básicos y print()
print("1. STRINGS BÁSICOS:")
nombre = "Jose Garcia"
frase = "Python es genial"
print("Nombre:", nombre)
print("Frase:", frase)
# Out:
# === MANIPULACIÓN DE TEXTOS Y COMPARACIONES ===
#
# 1. STRINGS BÁSICOS:
# Nombre: Jose Garcia
# Frase: Python es genial

# %% [markdown]
# # Sección nueva

# %%
# 2. Métodos upper() y lower()
print("\n2. CONVERSIÓN MAYÚSCULAS/MINÚSCULAS:")
print("Original:", nombre)
print("Upper():", nombre.upper())
print("Lower():", nombre.lower())
print("Title():", nombre.title())
# Out:
# 2. CONVERSIÓN MAYÚSCULAS/MINÚSCULAS:
# Original: Jose Garcia
# Upper(): JOSE GARCIA
# Lower(): jose garcia
# Title(): Jose Garcia

# %%
# 3. F-strings (formatted strings)
print("\n3. F-STRINGS (CADENAS FORMATEADAS):")
nombre = "Jesus"
edad = 25
altura = 1.80
print(f"Hola {nombre}, tienes {edad} años y mides {altura}m")
print(f"En 5 años tendrás {edad + 5} años")
print(f"Nombre en mayúsculas: {nombre.upper()}")
# Out:
# 3. F-STRINGS (CADENAS FORMATEADAS):
# Hola Jesus, tienes 25 años y mides 1.8m
# En 5 años tendrás 30 años
# Nombre en mayúsculas: JESUS

# %%
# 4. Métodos útiles de strings
print("\n4. MÉTODOS ÚTILES DE STRINGS:")
texto = "  Python es divertido  "
print(f"Original: '{texto}'")
print(f"Strip(): '{texto.strip()}'")
print(f"Replace(): '{texto.replace('divertido', 'poderoso')}'")
print(f"Split(): {texto.strip().split(' ')}")
print(f"Len(): {len(texto)} caracteres")
# Out:
# 4. MÉTODOS ÚTILES DE STRINGS:
# Original: '  Python es divertido  '
# Strip(): 'Python es divertido'
# Replace(): '  Python es poderoso  '
# Split(): ['Python', 'es', 'divertido']
# Len(): 23 caracteres

# %%
# 5. Operadores de comparación con números
print("\n5. OPERADORES DE COMPARACIÓN (NÚMEROS):")
a = 10
b = 5
c = 10
print(f"a = {a}, b = {b}, c = {c}")
print(f"a == b: {a == b}")  # Igual
print(f"a != b: {a != b}")  # Diferente
print(f"a > b: {a > b}")    # Mayor que
print(f"a < b: {a < b}")    # Menor que
print(f"a >= c: {a >= c}")  # Mayor o igual
print(f"a <= b: {a <= b}")  # Menor o igual
# Out:
# 5. OPERADORES DE COMPARACIÓN (NÚMEROS):
# a = 10, b = 5, c = 10
# a == b: False
# a != b: True
# a > b: True
# a < b: False
# a >= c: True
# a <= b: False

# %%
# 6. Operadores de comparación con textos
print("\n6. OPERADORES DE COMPARACIÓN (TEXTOS):")
texto1 = "Hola"
texto2 = "hola"
texto3 = "HOLA"
print(f"texto1 = '{texto1}', texto2 = '{texto2}', texto3 = '{texto3}'")
print(f"texto1 == texto2: {texto1 == texto2}")
print(f"texto1.lower() == texto2.lower(): {texto1.lower() == texto2.lower()}")
print(f"texto1.upper() == texto3.upper(): {texto1.upper() == texto3.upper()}")
print(f"'Python' > 'Java': {'Python' > 'Java'}")  # Comparación alfabética
# Out:
# 6. OPERADORES DE COMPARACIÓN (TEXTOS):
# texto1 = 'Hola', texto2 = 'hola', texto3 = 'HOLA'
# texto1 == texto2: False
# texto1.lower() == texto2.lower(): True
# texto1.upper() == texto3.upper(): True
# 'Python' > 'Java': True

# %%
# 7. Ejemplo práctico combinado
print("\n7. EJEMPLO PRÁCTICO COMBINADO:")
usuario = "  MARIA  "
contraseña = "secreto"

# Limpiar y formatear datos
usuario_limpio = usuario.strip().title()
print(f"Usuario original: '{usuario}'")
print(f"Usuario formateado: '{usuario_limpio}'")

# Verificaciones
print(f"¿Usuario no está vacío? {len(usuario_limpio) > 0}")
print(f"¿Contraseña tiene más de 5 caracteres? {len(contraseña) > 5}")
print(f"¿Usuario es 'Maria'? {usuario_limpio == 'Maria'}")

print("\n¡Programa terminado! 🐍")
# Out:
# 7. EJEMPLO PRÁCTICO COMBINADO:
# Usuario original: '  MARIA  '
# Usuario formateado: 'Maria'
# ¿Usuario no está vacío? True
# ¿Contraseña tiene más de 5 caracteres? True
# ¿Usuario es 'Maria'? True
#
# ¡Programa terminado! 🐍
